# %%
import pandas as pd

# %%
df=pd.read_csv('imdb.csv')

# %%
df.head()
# Out:
#                Director Film_Country         Film_Date  \
# 0        Frank Darabont          USA   14 October 1994
# 1     Christopher Nolan          USA      18 July 2008
# 2  Francis Ford Coppola          USA  18 December 1974
# 3        Hayao Miyazaki          USA  19 December 1997
# 4  Francis Ford Coppola          USA     24 March 1972
#
#                   Film_Name  Film_Rate  \
# 0  The Shawshank Redemption        9.3
# 1           The Dark Knight        9.0
# 2    The Godfather: Part II        9.0
# 3         Princess Mononoke        8.4
# 4             The Godfather        9.2
#
#                                        Stars
# 0      Tim Robbins,Morgan Freeman,Bob Gunton
# 1  Christian Bale,Heath Ledger,Aaron Eckhart
# 2     Al Pacino,Robert De Niro,Robert Duvall
# 3     Yôji Matsuda,Yuriko Ishida,Yûko Tanaka
# 4         Marlon Brando,Al Pacino,James Caan

# %%
films=len(df)

# %%
films
# Out:
# 328

# %%
new_df=df[['Film_Name','Film_Date','Film_Country','Film_Rate','Director','Stars']]
new_df
# Out:
#                                          Film_Name         Film_Date  \
# 0                         The Shawshank Redemption   14 October 1994
# 1                                  The Dark Knight      18 July 2008
# 2                           The Godfather: Part II  18 December 1974
# 3                                Princess Mononoke  19 December 1997
# 4                                    The Godfather     24 March 1972
# ..                                             ...               ...
# 323                                   12 Angry Men     10 April 1957
# 324                 The Good, the Bad and the Ugly  29 December 1967
# 325                                   Pulp Fiction   14 October 1994
# 326  The Lord of the Rings: The Return of the King  17 December 2003
# 327                                     Fight Club   15 October 1999
#
#     Film_Country  Film_Rate              Director  \
# 0            USA        9.3        Frank Darabont
# ...

# %%
film_rated=new_df.sort_values(by="Film_Rate",ascending=False,ignore_index=True)
film_rated
# Out:
#                                      Film_Name         Film_Date Film_Country  \
# 0                     The Shawshank Redemption   14 October 1994          USA
# 1                              The Chaos Class        April 1975       Turkey
# 2                                The Godfather     24 March 1972          USA
# 3                             Leyla and Mecnun         TV Series    2011–2014
# 4                       The Godfather: Part II  18 December 1974          USA
# ..                                         ...               ...          ...
# 323                               Bilincsizler  26 December 2015       Turkey
# 324  The Hobbit: The Battle of the Five Armies  17 December 2014          USA
# 325                                   Insomnia       24 May 2002          USA
# 326                              Conquest 1453     25 April 2012          USA
# 327                             Sekiz Cinayeti       19 May 2013       Turkey
#
# ...
